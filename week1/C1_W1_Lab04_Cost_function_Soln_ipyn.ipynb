# %% [markdown]
# <a href="https://colab.research.google.com/github/yMugrelo/ML/blob/main/week1/C1_W1_Lab04_Cost_function_Soln_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tools

# %%
import sys


import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

# %% [markdown]
# Computing Cost

# %%
def compute_cost(x, y, w, b):
  m = x.shape[0]
  cost_sum = 0
  for i in range(m):
    f_Wb = w*x[i]+b
    cost = (f_Wb - y[i])**2
    cost_sum = cost_sum + cost
  total_cost = (1/(2*m))*cost_sum
  return total_cost

print(compute_cost(x_train, y_train, 2, 300))
# Out:
# 9605.0

# %% [markdown]
# intuition

# %%
def plt_intuition(x_train, y_train):
    w_range = np.array([200-200, 200+200])
    tmp_b = 100

    w_array = np.arange(*w_range, 5)
    cost = np.zeros_like(w_array)

    for i in range(len(w_array)):
        tmp_w = w_array[i]
        cost[i] = compute_cost(x_train, y_train, tmp_w, tmp_b)

    return w_array, cost
w_array, cost = plt_intuition(x_train, y_train)

plt.plot(w_array, cost, c='b', label='Cost')
plt.xlabel('w')
plt.ylabel('Cost')
plt.title('Cost vs w')
plt.legend()
plt.show()
